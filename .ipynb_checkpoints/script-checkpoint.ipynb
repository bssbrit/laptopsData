# %%
import pandas as pd

# %%
noteData = pd.read_csv('EbayPcLaptopsAndNetbooksUnclean.csv')
cleanNoteData = pd.read_csv('EbayPcLaptopsAndNetbooksClean.csv')

# %%
noteData.drop_duplicates(inplace = True)

# %%
noteData.drop(columns = ['Manufacturer Color','Rating', 'Ratings Count','Country Region Of Manufacture'], inplace = True)

# %%
noteData['Brand'] = noteData['Brand'].str.lower()

# %%
noteData['Price'] = noteData['Price'].str.split(' to ').str[0].str.strip().str.strip('$')

# %%
noteData[['Condition', 'Condition Description']] = noteData['Condition'].str.split(r'[-:|An]',n=1,expand=True)

# %%
noteData[['Brand', 'Color']] = noteData[['Brand', 'Color']].fillna("other")

# %%
noteData[['Seller Note']] = noteData[['Seller Note']].fillna("Undefined")

# %%
colunas = ['Brand',
 'Color',
           'Price',
 'Condition',
 'Condition Description',
 'Features',
 'GPU',
 'Hard Drive Capacity',
 'Maximum Resolution',
 'Model',
 'OS',
 
 'Processor',
 'Processor Speed',
 'Ram Size',
 'Release Year',
 'SSD Capacity',
 'Screen Size',
 'Seller Note',
 'Storage Type',
 'Type']

noteData[colunas]
# Out:
#        Brand  Color   Price   Condition  \
# 0      chuwi   Gray  303.68         New
# 1       dell  Black  399.99  Very Good
# 2       dell  Black  175.00        Used
# 3         hp  Black   84.99       Good
# 4       dell  other  101.22       Good
# ...      ...    ...     ...         ...
# 6600    acer  other   93.26         New
# 6601    dell  Black  424.83        Used
# 6611   other  other  385.23         New
# 6612      hp  other   90.92         New
# 6618  lenovo  Black  567.74         NaN
#
#                                   Condition Description  \
# 0      A brand-new, unused, unopened, undamaged item...
# 1      RefurbishedThe item shows minimal wear and is...
# 2     n item that has been used previously. The item...
# 3      RefurbishedThe item shows moderate wear and i...
# 4      RefurbishedThe item shows moderate wear and i...
# ...                                                 ...
# 6600   A brand-new, unused, unopened, undamaged item...
# ...

# %%
#pd.set_option('display.max_colwidth', 1)
noteData[['Features']].head()
# Out:
#                                             Features
# 0  Backlit Keyboard,  Built-in Microphone,  Built...
# 1  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 2  10/100 LAN Card, Backlit Keyboard, Bluetooth, ...
# 3  Bluetooth, Built-in Microphone, Built-in Webca...
# 4  10/100 LAN Card, Built-in Microphone, Built-in...

# %%
noteData
# Out:
#        Brand   Price   Condition  \
# 0      chuwi  303.68         New
# 1       dell  399.99  Very Good
# 2       dell  175.00        Used
# 3         hp   84.99       Good
# 4       dell  101.22       Good
# ...      ...     ...         ...
# 6600    acer   93.26         New
# 6601    dell  424.83        Used
# 6611   other  385.23         New
# 6612      hp   90.92         New
# 6618  lenovo  567.74         NaN
#
#                                             Seller Note  \
# 0                                             Undefined
# 1     “AAA PCs is a Microsoft Authorized Refurbisher...
# 2     “Well kept, fully functional, includes battery...
# 3     “1-Year Allstate warranty. The original HP cha...
# 4     “Laptops is tested & fully working with some s...
# ...                                                 ...
# 6600                                          Undefined
# 6601                                          Undefined
# ...

# %%
cleanNoteData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4183 entries, 0 to 4182
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Brand                     4183 non-null   object
#  1   Price                     4183 non-null   float64
#  2   Currency                  4183 non-null   object
#  3   Color                     4183 non-null   object
#  4   Features                  1993 non-null   object
#  5   Condition                 4183 non-null   object
#  6   Condition Description     4183 non-null   object
#  7   Seller Note               4183 non-null   object
#  8   GPU                       4183 non-null   object
#  9   Processor                 4183 non-null   object
#  10  Processor Speed           2090 non-null   object
#  11  Processor Speed Unit      4183 non-null   object
#  12  Type                      4183 non-null   object
# ...

# %%
noteData['Price'] = noteData['Price'].astype(float)
noteData.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 noteData['Price'] = noteData['Price'].astype(float)
#       2 noteData.info()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
# ...

# %%
noteData['Price'] = noteData['Price'].replace(',', '.')

# %%
noteData[noteData['Price'] == '1,179.42'].index

# %%
#noteData = noteData.drop(noteData[noteData['Price'] == '1,197.49'].index)
