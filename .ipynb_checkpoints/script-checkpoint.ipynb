# %%
import pandas as pd

# %%
noteData = pd.read_csv('EbayPcLaptopsAndNetbooksUnclean.csv')
cleanNoteData = pd.read_csv('EbayPcLaptopsAndNetbooksClean.csv')

# %%
noteData.drop_duplicates(inplace = True)

# %%
noteData.drop(columns = ['Rating', 'Ratings Count'], inplace = True)

# %%
noteData['Brand'] = noteData['Brand'].str.lower()

# %%
noteData.head(50)
# Out:
#         Brand  Price                                          Condition  \
# 0       chuwi    NaN  New: A brand-new, unused, unopened, undamaged ...
# 1        dell    NaN  Very Good - RefurbishedThe item shows minimal ...
# 2        dell    NaN  UsedAn item that has been used previously. The...
# 3          hp    NaN  Good - RefurbishedThe item shows moderate wear...
# 4        dell    NaN  Good - RefurbishedThe item shows moderate wear...
# 5        acer    NaN                                                NaN
# 6          hp    NaN                                                NaN
# 7        acer    NaN                                                NaN
# 8        dell    NaN  Excellent - Refurbished: The item is in like-n...
# 9          hp    NaN                                                NaN
# 10     lenovo    NaN  UsedAn item that has been used previously. The...
# 11    samsung    NaN  New: A brand-new, unused, unopened, undamaged ...
# 12       acer    NaN                                                NaN
# 13      chuwi    NaN  New: A brand-new, unused, unopened, undamaged ...
# 14      chuwi    NaN  New: A brand-new, unused, unopened, undamaged ...
# 15       dell    NaN  UsedAn item that has been used previously. The...
# 16       dell    NaN  UsedAn item that has been used previously. The...
# 17       dell    NaN  UsedAn item that has been used previously. The...
# 18       acer    NaN  UsedAn item that has been used previously. The...
# 19       dell    NaN  Very Good - RefurbishedThe item shows minimal ...
# 20       dell    NaN  Open box: An item in excellent, new condition ...
# 21       dell    NaN                                                NaN
# 22       dell    NaN  UsedAn item that has been used previously. The...
# 23        NaN    NaN  UsedAn item that has been used previously. The...
# 24         hp    NaN  New: A brand-new, unused, unopened, undamaged ...
# 25  microsoft    NaN  UsedAn item that has been used previously. The...
# 26     lenovo    NaN                                                NaN
# 27         hp    NaN  New: A brand-new, unused, unopened, undamaged ...
# 28        NaN    NaN  UsedAn item that has been used previously. The...
# 29       dell    NaN  Very Good - RefurbishedThe item shows minimal ...
# 30      chuwi    NaN  New: A brand-new, unused, unopened, undamaged ...
# 31         hp    NaN  Very Good - RefurbishedThe item shows minimal ...
# 32     lenovo    NaN  UsedAn item that has been used previously. The...
# 33         hp    NaN  Very Good - RefurbishedThe item shows minimal ...
# 34      chuwi    NaN  New: A brand-new, unused, unopened, undamaged ...
# 35     lenovo    NaN                                                NaN
# 36     lenovo    NaN  UsedAn item that has been used previously. The...
# 37       dell    NaN  Used: An item that has been used previously. T...
# 38       dell    NaN  UsedAn item that has been used previously. The...
# 39      chuwi    NaN  New: A brand-new, unused, unopened, undamaged ...
# 40     lenovo    NaN  UsedAn item that has been used previously. The...
# 41       dell    NaN  New: A brand-new, unused, unopened, undamaged ...
# 42       dell    NaN  Used: An item that has been used previously. T...
# 43         lg    NaN  Used: An item that has been used previously. T...
# 44         hp    NaN  Used: An item that has been used previously. T...
# 45         hp    NaN  Very Good - RefurbishedThe item shows minimal ...
# 46       dell    NaN  UsedAn item that has been used previously. The...
# 47         hp    NaN  Very Good - RefurbishedThe item shows minimal ...
# 48  microsoft    NaN  For parts or not workingAn item that does not ...
# 49         hp    NaN  UsedAn item that has been used previously. The...
#
#                                           Seller Note  \
# 0                                                 NaN
# 1   “AAA PCs is a Microsoft Authorized Refurbisher...
# 2   “Well kept, fully functional, includes battery...
# 3   “1-Year Allstate warranty. The original HP cha...
# 4   “Laptops is tested & fully working with some s...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  “Very good condition. very good performance,  ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  “This dell computer was used before and will s...
# 16  “Good working used condition - wear marks from...
# 17  “Tested and guaranteed by certified dell lapto...
# 18  “Acer Chromebook C731 in certified excellent, ...
# 19  “AAA PCs is a Microsoft Authorized Refurbisher...
# 20                                                NaN
# 21                                                NaN
# 22  “This dell computer was used before and will s...
# 23                                       “s. Details”
# 24                                                NaN
# 25  “The device is in good working & and cosmetic ...
# 26                                                NaN
# 27                                                NaN
# 28  “Sehr guter technischer und optischer Zustand....
# 29  “The item shows minimal wear and is backed by ...
# 30                                                NaN
# 31  “AAA PCs is a Microsoft Authorized Refurbisher...
# 32  “Fully tested working. Windows 10 Home install...
# 33  ““Tested working. The Unit shows minor cosmeti...
# 34                                                NaN
# 35                                                NaN
# 36  “Lenovo ThinkPad T440 in used but well-maintai...
# 37                                                NaN
# 38  “An item that has been used previously. The it...
# 39                                                NaN
# 40  “Comprenew Grade B: Full Functionality | All F...
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45  ““Tested working. The Unit shows minor cosmeti...
# 46  “Certified in Excellent  Working Condition by ...
# 47  “1-Year Allstate warranty. The original HP cha...
# 48  “Surface pro 4. 8gb 256gb version Screen glass...
# 49  “MINT CONDITION, LIKE NEW!  HP Chromebook 11 G...
#
#                         Processor      Screen Size Manufacturer Color  \
# 0                       Quad Core            14 in                NaN
# 1          Intel Core i7 8th Gen.            14 in                NaN
# 2             Intel Core i5-6300U            14 in                NaN
# 3                 Intel Celeron N          11.6 in                NaN
# 4          Intel Core i5 6th Gen.    Minimum 12.5"                NaN
# 5                   Intel Celeron          11.6 in              Black
# 6                   Intel Celeron          11.6 in                NaN
# 7         Intel Celeron Dual-Core        11.6 inin                NaN
# 8                          i7 7th            14 in                NaN
# 9         Intel Core i3 10th Gen.            14 in     Mineral Silver
# 10                8350U,  Core i5            14 in                NaN
# 11        Intel Core i5 12th Gen.          13.3 in                NaN
# 12                Intel Celeron N          11.6 in        Pure Silver
# 13  Intel Celeron Processor N4100          14.1 in                NaN
# 14            Intel Core i5-8259U            14 in                NaN
# 15         Intel Core i5 7th Gen.             2 in                NaN
# 16         Intel Core i5 8th Gen.          15.6 in                NaN
# 17                  Intel Celeron            11 in                NaN
# 18                Intel Celeron N          11.6 in                NaN
# 19         Intel Core i7 8th Gen.            14 in                NaN
# 20        Intel Core i7 13th Gen.            16 in                NaN
# 21                    AMD Ryzen 5            14 in                NaN
# 22         Intel Core i5 6th Gen.          12.5 in              Black
# 23                            NaN              NaN                NaN
# 24                       i5-8365U            13 in                NaN
# 25         Intel Core i5 4th Gen.            12 in                NaN
# 26                Intel Celeron N          11.6 in                NaN
# 27           Intel Core i5-1135G7          15.6 in                NaN
# 28                            NaN              NaN                NaN
# 29         Intel Core i5 7th Gen.          15.6 in                NaN
# 30                      Quad Core          15.6 in                NaN
# 31         Intel Core i7 8th Gen.            14 in                NaN
# 32            Intel Celeron N3160          11.6 in                NaN
# 33                       i5-7200U          15.6 in                NaN
# 34            Intel Celeron N4100          14.1 in                NaN
# 35        Intel Core i7 12th Gen.            16 in         Storm Gray
# 36            Intel Core i5-4300U            14 in                NaN
# 37                      i7-7820HQ  15.6" 1080P FHD                NaN
# 38            Intel Core i5-4200U            14 in                NaN
# 39            Intel Celeron N5100          13.5 in                NaN
# 40            Intel Core i5-8250U            14 in                NaN
# 41                    AMD Ryzen 5          15.6 in                NaN
# 42         Intel Core i5 6th Gen.            14 in                NaN
# 43         Intel Core i7 13th Gen          17.3 in                NaN
# 44                  Intel Celeron            14 in                NaN
# 45         Intel Core i3 6th Gen.          15.6 in                NaN
# 46                       Intel i5          15.6 in                NaN
# 47                  Intel Celeron          11.6 in                NaN
# 48                  Intel Core i5          12.5 in                NaN
# 49                Intel Celeron N          11.6 in                NaN
#
#                  Color    Ram Size                           SSD Capacity  \
# 0                 Gray        8 GB  1 Used,  1 support Max 1TB M.2 Extend
# 1                Black         NaN                                    NaN
# 2                Black       16 GB                                 500 GB
# 3                Black        4 GB                                    NaN
# 4                  NaN        8 GB                                 256 GB
# 5                Black        4 GB                                  16 GB
# 6                Black        4 GB                                   16GB
# 7   Gray, Granite Gray         2GB                                    NaN
# 8                Black       16 GB                                 500 GB
# 9               Silver        8 GB                                  64 GB
# 10               Black       16 GB                                 128 GB
# 11                 NaN         NaN                                    NaN
# 12              Silver        4 GB                                  32 GB
# 13                Gray        8 GB                                 256 GB
# 14                Gray        8 GB                                 512 GB
# 15               Black        8 GB                                 128 GB
# 16               Black       16 GB                                 512 GB
# 17               Black        4 GB                                 128 GB
# 18                Gray        4 GB                                  16 GB
# 19               Black         NaN                                    NaN
# 20                 NaN       32 GB                                   1 TB
# 21              Silver       16 GB                                 512 GB
# 22               Black        8 GB                                 256 GB
# 23                 NaN         NaN                                    NaN
# 24              Silver       16 GB                                 512 GB
# 25                Gray        4 GB                                 128 GB
# 26               Black        4 MB                                  16 GB
# 27      Natural Silver  Up to 32GB                              Up to 2TB
# 28                 NaN         NaN                                    NaN
# 29               Black       16 GB                                 512 GB
# 30                Gray       16 GB                                 512 GB
# 31               Black         NaN                                    NaN
# 32               Black         NaN                                 128 GB
# 33               Black       16 GB                                 512 GB
# 34                Gray        8 GB                                 256 GB
# 35                Gray       16 GB                                 512 GB
# 36          Dark Brown        8 GB                                 256 GB
# 37               Black       16 GB                                 512 GB
# 38               Black        8 GB                                 256 GB
# 39                Gray       12 GB                                 512 GB
# 40               Black       16 GB                                 256 GB
# 41        Carbon Black       16 GB                                 512 GB
# 42               Black        8 GB                                    NaN
# 43               Black       16 GB                                 512 GB
# 44          Grey/Black       16 GB                                  16 GB
# 45               Black        8 GB                                 512 GB
# 46                 NaN        8 GB                                 256 GB
# 47               Multi        4 GB                                  16 GB
# 48                 NaN      256 GB                                 256 GB
# 49               Black        4 GB                                  16 GB
#
#     ...                     Processor Speed                              Type  \
# 0   ...                  Max up to 3.80 GHz                   Notebook/Laptop
# 1   ...  4.20 GHz (1.90 GHz Base Frequency)                   Notebook/Laptop
# 2   ...                            2.40 GHz                   Notebook/Laptop
# 3   ...                            2.40 GHz                   Notebook/Laptop
# 4   ...                    Minimum 1.40 GHz                   Notebook/Laptop
# 5   ...                            1.60 GHz                            Laptop
# 6   ...                            1.60 GHz                   Notebook/Laptop
# 7   ...                       1.00 GHz.4ghz                           Netbook
# 8   ...                            2.80 GHz                   Notebook/Laptop
# 9   ...                            2.10 GHz                   Notebook/Laptop
# 10  ...                            1.70 GHz                   Notebook/Laptop
# 11  ...                                 NaN                               NaN
# 12  ...                            1.10 GHz                   Notebook/Laptop
# 13  ...                            2.80 GHz                   Notebook/Laptop
# 14  ...                            3.80 GHz                   Notebook/Laptop
# 15  ...                                 NaN                   Notebook/Laptop
# 16  ...                            1.60 GHz                   Notebook/Laptop
# 17  ...                            1.10 GHz                   Notebook/Laptop
# 18  ...                            1.60 GHz                   Notebook/Laptop
# 19  ...  4.20 GHz (1.90 GHz Base Frequency)                   Notebook/Laptop
# 20  ...                            4.40 GHz                               NaN
# 21  ...                            2.30 GHz              N/A, Notebook/Laptop
# 22  ...                            2.60 GHz                   Notebook/Laptop
# 23  ...                                 NaN                               NaN
# 24  ...                            1.60 GHz                   Notebook/Laptop
# 25  ...                            1.90 GHz                   Notebook/Laptop
# 26  ...                            1.10 GHz                   Notebook/Laptop
# 27  ...                        Up to 4.2GHz                   Notebook/Laptop
# 28  ...                                 NaN                               NaN
# 29  ...  3.10 GHz (2.50 GHz Base Frequnecy)                   Notebook/Laptop
# 30  ...                        up to 3.4Ghz                   Notebook/Laptop
# 31  ...  4.20 GHz (1.90 GHz Base Frequency)                   Notebook/Laptop
# 32  ...                            1.60 GHz  Convertible 2-in-1 Laptop/Tablet
# 33  ...                            2.50 GHz                   Notebook/Laptop
# 34  ...                        up to 2.8GHZ                   Notebook/Laptop
# 35  ...                            3.50 GHz                   Notebook/Laptop
# 36  ...                             1.9 GHz                   Notebook/Laptop
# 37  ...                       2.8 to 3.9GHz                          Notebook
# 38  ...                            1.60 GHz                   Notebook/Laptop
# 39  ...                            2.80 GHz                   Notebook/Laptop
# 40  ...                                 NaN                               NaN
# 41  ...                        Up to 4.5GHz                   Notebook/Laptop
# 42  ...                            2.40 GHz                   Notebook/Laptop
# 43  ...                                 NaN                   Notebook/Laptop
# 44  ...                            2.16 GHz                   Notebook/Laptop
# 45  ...                            2.30 GHz                   Notebook/Laptop
# 46  ...                            2.30 GHz                               NaN
# 47  ...                                 2.4                   Notebook/Laptop
# 48  ...                                 NaN                   Notebook/Laptop
# 49  ...                             1.6 GHz                        Chromebook
#
#            Release Year Maximum Resolution                       Model  \
# 0                  2021        2160 x 1440                  CoreBook X
# 1   Refurbished in 2023        1920 x 1080          Dell Latitude 7490
# 2                  2019        1920 x 1080         Dell Latitude E5470
# 3                   NaN         1366 x 768         HP Chromebook 11 G6
# 4                  2015         1366 x 768              Various Models
# 5                  2017         1366 x 768       Chromebook C738T-C44Z
# 6                  2017                NaN         HP Chromebook 11 G5
# 7                   NaN                NaN        Chromebook C720-2848
# 8                   NaN        1920 x 1080          Dell Latitude 7480
# 9                  2020        1920 x 1080        Samsung Chromebook 3
# 10                  NaN        1920 x 1080                 Lenovo T480
# 11                  NaN                NaN                         NaN
# 12                 2020         1366 x 768         Acer Chromebook 311
# 13                 2021        1920 x 1080           CHUWI Lapbook Pro
# 14                 2021        2160 x 1440            CHUWI CoreBook X
# 15                  NaN        1920 x 1080          Dell Latitude 5289
# 16                  NaN        1920 x 1080         Dell Latitude E5500
# 17                 2019         1366 x 768          Dell Latitude 3189
# 18                 2018         1366 x 768        Acer Chromebook C731
# 19  Refurbished in 2023        1920 x 1080          Dell Latitude 7400
# 20                 2023        2560 x 1600                16 Plus 7630
# 21                  NaN        1920 x 1080       Dell Inspiron 14 5425
# 22                 2013        1920 x 1080          Dell Latitude 5289
# 23                  NaN                NaN                         NaN
# 24                 2019        3000 x 2000              HP Elite X2 G4
# 25                  NaN        2160 x 1440     Microsoft Surface Pro 3
# 26                  NaN         1366 x 768                 Lenovo 100e
# 27                 2023        1920 x 1080             HP 15 Essential
# 28                  NaN                NaN                         NaN
# 29  Refurbished in 2023        1920 x 1080          Dell Latitude 5580
# 30                 2023        1920 x 1080               GemiBook Plus
# 31  Refurbished in 2023        1920 x 1080         HP EliteBook 840 G6
# 32                  NaN         1366 x 768           Yoga 11e 3rd Gen.
# 33                  NaN                NaN           HP ProBook 650 G3
# 34                  NaN        1920 x 1080           CHUWI LapBook Pro
# 35                 2022        2560 x 1600  Lenovo Legion 5 Pro 16IAH7
# 36                  NaN                NaN        Lenovo ThinkPad T440
# 37                  NaN        1920 x 1080                       E5580
# 38                 2014         1366 x 768         Dell Latitude E5440
# 39                 2022        2256 x 1504              CHUWI FreeBook
# 40                  NaN                NaN                        L380
# 41                 2023        1920 x 1080       Dell Inspiron 15 3535
# 42                 2019        1920 x 1080                        5414
# 43                  NaN                NaN            17ZB90R-K.AAC7U1
# 44                  NaN         1366 x 768              HP T4M32UT#ABA
# 45                  NaN                NaN              ProBook 650 G2
# 46                  NaN                NaN         Dell Latitude E5550
# 47                 2019         1366 x 768         Chromebook 11 G6 EE
# 48                  NaN                NaN       Microsoft Surface Pro
# 49                  NaN         1366 x 768          Samsung ChromeBook
#
#                  OS                                           Features  \
# 0   Windows 11 Home  Backlit Keyboard,  Built-in Microphone,  Built...
# 1    Windows 11 Pro  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 2    Windows 10 Pro  10/100 LAN Card, Backlit Keyboard, Bluetooth, ...
# 3         Chrome OS  Bluetooth, Built-in Microphone, Built-in Webca...
# 4        Windows 10  10/100 LAN Card, Built-in Microphone, Built-in...
# 5         Chrome OS                             Touchscreen, Bluetooth
# 6         Chrome OS                         Bluetooth, Built-in Webcam
# 7         Chrome OS                                                NaN
# 8        win 11 pro                                              Wi-Fi
# 9         Chrome OS  Touchscreen, Bluetooth, Built-in Webcam, Wi-Fi...
# 10   Windows 11 Pro              Built-in Microphone,  Built-in Webcam
# 11              NaN                                                NaN
# 12        Chrome OS                                          Bluetooth
# 13  Windows 11 Home                                              Wi-Fi
# 14       Windows 10  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 15   Windows 10 Pro  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 16     Not Included  Backlit Keyboard, Bluetooth, Built-in Webcam, ...
# 17   Windows 10 Pro  Bluetooth, Built-in Microphone, Built-in Webca...
# 18        Chrome OS  Bluetooth,  Built-in Microphone,  Built-in Web...
# 19   Windows 11 Pro  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 20  Windows 11 Home  3D Camera,  Backlit Keyboard,  Bluetooth,  Bui...
# 21  Windows 11 Home                                                NaN
# 22       Windows 10  Bluetooth,  Built-in Microphone,  Built-in Webcam
# 23              NaN                                                NaN
# 24          FreeDOS  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 25   Windows 10 Pro                                                NaN
# 26        Chrome OS  Touchscreen, Bluetooth, Built-in Webcam, Wi-Fi...
# 27  Windows 11 Home  Bluetooth, Built-in Microphone, Built-in Webca...
# 28              NaN                                                NaN
# 29   Windows 10 Pro  Backlit Keyboard, Bluetooth, Built-in Micropho...
# 30  Windows 11 Home  Built-in Microphone,  Built-in Webcam,  Blueto...
# 31   Windows 11 Pro  Bluetooth,  Built-in Microphone,  Built-in Web...
# 32  Windows 10 Home  10/100 LAN Card, Bluetooth, Built-in Microphon...
# 33   Windows 11 Pro  Bluetooth, Built-in Microphone, Built-in Webca...
# 34  Windows 11 Home  Bluetooth, Backlit Keyboard, Built-in Micropho...
# 35  Windows 11 Home                                   Bluetooth, Wi-Fi
# 36              NaN                                        Touchscreen
# 37   Windows 11 Pro                  Backlit Keyboard, Built-in Webcam
# 38  Windows 10 Home  Bluetooth,  Built-in Microphone,  Built-in Web...
# 39  Windows 10 Home  Bluetooth, Built-in Webcam, Convertible 2-in-1...
# 40     Not Included  Built-in Microphone, Built-in Webcam, Converti...
# 41  Windows 11 Home  Bluetooth, Wi-Fi, MaxxAudio Pro, Media Card Re...
# 42     Not Included  Bluetooth,  Built-in Microphone,  Built-in Web...
# 43  Windows Home 11                                                NaN
# 44        Chrome OS                                              Wi-Fi
# 45   Windows 10 Pro  Bluetooth,  Built-in Webcam,  Optical Drive,  ...
# 46   Windows 10 Pro                                                NaN
# 47        Chrome OS  Bluetooth,  Built-in Webcam,  Wi-Fi,  Built-in...
# 48     Not Included  10/100 LAN Card, Backlit Keyboard, Bluetooth, ...
# 49        Chrome OS  Bluetooth,  Built-in Microphone,  Built-in Web...
#
#    Hard Drive Capacity Country Region Of Manufacture             Storage Type
# 0           512 GB SSD                         China  SSD (Solid State Drive)
# 1                 2 TB                           NaN  SSD (Solid State Drive)
# 2               500 GB                         China  SSD (Solid State Drive)
# 3                16 GB                           NaN                     eMMC
# 4               NO HDD                           NaN  SSD (Solid State Drive)
# 5                  NaN                           NaN  SSD (Solid State Drive)
# 6                16 GB                           NaN  SSD (Solid State Drive)
# 7                 16GB                           NaN                      NaN
# 8               512 GB                           NaN  SSD (Solid State Drive)
# 9                  NaN                           NaN                     eMMC
# 10                 NaN                           NaN  SSD (Solid State Drive)
# 11                 NaN                           NaN                      NaN
# 12                 NaN                           NaN                     eMMC
# 13              256 GB                           NaN  SSD (Solid State Drive)
# 14              512 GB                           NaN                HDD + SSD
# 15              128 GB                           NaN  SSD (Solid State Drive)
# 16                 NaN                           NaN  SSD (Solid State Drive)
# 17              128 GB                           NaN  SSD (Solid State Drive)
# 18               16 GB                           NaN  SSD (Solid State Drive)
# 19                2 TB                           NaN  SSD (Solid State Drive)
# 20                1 TB                           NaN  SSD (Solid State Drive)
# 21                 NaN                           NaN  SSD (Solid State Drive)
# 22              256 GB                 United States  SSD (Solid State Drive)
# 23                 NaN                           NaN                      NaN
# 24                 NaN                           NaN  SSD (Solid State Drive)
# 25              128 GB                           NaN  SSD (Solid State Drive)
# 26                 NaN                           NaN                     eMMC
# 27           Up to 2TB                           NaN  SSD (Solid State Drive)
# 28                 NaN                           NaN                      NaN
# 29              512 GB                           NaN  SSD (Solid State Drive)
# 30              512 GB                         China  SSD (Solid State Drive)
# 31                2 TB                           NaN  SSD (Solid State Drive)
# 32                 NaN                           NaN  SSD (Solid State Drive)
# 33                 NaN                           NaN  SSD (Solid State Drive)
# 34              256 GB                           NaN  SSD (Solid State Drive)
# 35                 NaN                           NaN  SSD (Solid State Drive)
# 36              256 GB                           NaN  SSD (Solid State Drive)
# 37           512GB SSD                           NaN  SSD (Solid State Drive)
# 38                 NaN                           NaN  SSD (Solid State Drive)
# 39               12 GB                           NaN  SSD (Solid State Drive)
# 40                 NaN                           NaN                      NaN
# 41              512 GB                           NaN  SSD (Solid State Drive)
# 42                8 GB                           NaN  SSD (Solid State Drive)
# 43                 NaN                           NaN                      NaN
# 44               16 GB                           NaN  SSD (Solid State Drive)
# 45                 NaN                           NaN  SSD (Solid State Drive)
# 46              256 GB                           NaN  SSD (Solid State Drive)
# 47               16 GB                           NaN                     eMMC
# 48              256 GB                           NaN  SSD (Solid State Drive)
# 49               16 GB                           NaN                     eMMC
#
# [50 rows x 21 columns]

# %%
noteData['Price'].str.lsptrip('$')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 noteData['Price'].str.lsptrip('$')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/strings/accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/strings/accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
noteData['Price'] = noteData['Price'].str.split('to')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 noteData['Price'] = noteData['Price'].str.split('to')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/strings/accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/strings/accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
noteData['Price']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 6600   NaN
# 6601   NaN
# 6611   NaN
# 6612   NaN
# 6618   NaN
# Name: Price, Length: 4475, dtype: float64
