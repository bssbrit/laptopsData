# %%
import pandas as pd

# %%
noteData = pd.read_csv('EbayPcLaptopsAndNetbooksUnclean.csv')
cleanNoteData = pd.read_csv('EbayPcLaptopsAndNetbooksClean.csv')

# %%
noteData.drop_duplicates(inplace = True)

# %%
noteData.drop(columns = ['Rating', 'Ratings Count'], inplace = True)

# %%
noteData['Brand'] = noteData['Brand'].str.lower()

# %%
noteData['Price'] = noteData['Price'].str.split(' to ').str[0].str.strip().str.strip('$')

# %%
noteData['Price']
# Out:
# 0       303.68
# 1       399.99
# 2       175.00
# 3        84.99
# 4       101.22
#          ...
# 6600     93.26
# 6601    424.83
# 6611    385.23
# 6612     90.92
# 6618    567.74
# Name: Price, Length: 4475, dtype: object

# %%
noteData[['Condition', 'Condition Description']] = noteData['Condition'].str.split(':',n=1,expand=True)

# %%
noteData[pd.isna(noteData['Condition Description'])]
# Out:
#        Brand   Price                                          Condition  \
# 1       dell  399.99  Very Good - RefurbishedThe item shows minimal ...
# 2       dell  175.00  UsedAn item that has been used previously. The...
# 3         hp   84.99  Good - RefurbishedThe item shows moderate wear...
# 4       dell  101.22  Good - RefurbishedThe item shows moderate wear...
# 5       acer   49.99                                                NaN
# ...      ...     ...                                                ...
# 6469  lenovo  174.35                                                NaN
# 6472    dell  269.69  UsedAn item that has been used previously. The...
# 6517   apple  112.50  UsedAn item that has been used previously. The...
# 6543     NaN   92.62                                                NaN
# 6618  lenovo  567.74                                                NaN
#
#                                             Seller Note  \
# 1     “AAA PCs is a Microsoft Authorized Refurbisher...
# 2     “Well kept, fully functional, includes battery...
# 3     “1-Year Allstate warranty. The original HP cha...
# 4     “Laptops is tested & fully working with some s...
# 5                                                   NaN
# ...                                                 ...
# 6469                                                NaN
# 6472  “These units are fully functional and have all...
# 6517  “The laptop is in good working and cosmetic co...
# 6543                                                NaN
# 6618                                                NaN
#
#                    Processor    Screen Size Manufacturer Color  Color  \
# 1     Intel Core i7 8th Gen.          14 in                NaN  Black
# 2        Intel Core i5-6300U          14 in                NaN  Black
# 3            Intel Celeron N        11.6 in                NaN  Black
# 4     Intel Core i5 6th Gen.  Minimum 12.5"                NaN    NaN
# 5              Intel Celeron        11.6 in              Black  Black
# ...                      ...            ...                ...    ...
# 6469                     NaN            NaN                NaN    NaN
# 6472                   8265U            14"                NaN  Black
# 6517          Intel Core Duo        13.3 in                NaN  White
# 6543                     NaN            NaN                NaN    NaN
# 6618                     NaN            NaN                NaN  Black
#
#      Ram Size SSD Capacity  ...             Type         Release Year  \
# 1         NaN          NaN  ...  Notebook/Laptop  Refurbished in 2023
# 2       16 GB       500 GB  ...  Notebook/Laptop                 2019
# 3        4 GB          NaN  ...  Notebook/Laptop                  NaN
# 4        8 GB       256 GB  ...  Notebook/Laptop                 2015
# 5        4 GB        16 GB  ...           Laptop                 2017
# ...       ...          ...  ...              ...                  ...
# 6469      NaN          NaN  ...              NaN                  NaN
# 6472      8GB         1 TB  ...               NB                 2019
# 6517     2 GB          NaN  ...  Notebook/Laptop                  NaN
# 6543      NaN          NaN  ...              NaN                  NaN
# 6618      NaN          NaN  ...  Notebook/Laptop                  NaN
#
#      Maximum Resolution                  Model              OS  \
# 1           1920 x 1080     Dell Latitude 7490  Windows 11 Pro
# 2           1920 x 1080    Dell Latitude E5470  Windows 10 Pro
# 3            1366 x 768    HP Chromebook 11 G6       Chrome OS
# 4            1366 x 768         Various Models      Windows 10
# 5            1366 x 768  Chromebook C738T-C44Z       Chrome OS
# ...                 ...                    ...             ...
# 6469        1920 x 1080                    NaN             NaN
# 6472         1366 x 768          Latitude 5400  Windows 10 Pro
# 6517                NaN          Macbook A1181             NaN
# 6543                NaN                    NaN             NaN
# 6618                NaN                    NaN             NaN
#
#                                                Features Hard Drive Capacity  \
# 1     Backlit Keyboard, Bluetooth, Built-in Micropho...                2 TB
# 2     10/100 LAN Card, Backlit Keyboard, Bluetooth, ...              500 GB
# 3     Bluetooth, Built-in Microphone, Built-in Webca...               16 GB
# 4     10/100 LAN Card, Built-in Microphone, Built-in...              NO HDD
# 5                                Touchscreen, Bluetooth                 NaN
# ...                                                 ...                 ...
# 6469                                                NaN                 NaN
# 6472                                   Bluetooth, Wi-Fi                  No
# 6517                                                NaN              320 GB
# 6543                                                NaN                 NaN
# 6618                                                NaN                 NaN
#
#      Country Region Of Manufacture             Storage Type  \
# 1                              NaN  SSD (Solid State Drive)
# 2                            China  SSD (Solid State Drive)
# 3                              NaN                     eMMC
# 4                              NaN  SSD (Solid State Drive)
# 5                              NaN  SSD (Solid State Drive)
# ...                            ...                      ...
# 6469                           NaN                      NaN
# 6472                 United States                      NaN
# 6517                           NaN    HDD (Hard Disk Drive)
# 6543                           NaN                      NaN
# 6618                           NaN                      NaN
#
#      Condition Description
# 1                     None
# 2                     None
# 3                     None
# 4                     None
# 5                      NaN
# ...                    ...
# 6469                   NaN
# 6472                  None
# 6517                  None
# 6543                   NaN
# 6618                   NaN
#
# [1581 rows x 22 columns]

# %%
noteData.loc[pd.isna(noteData['Condition Description']), ['Condition', 'Condition Description']] = noteData['Condition'].str.split('-', n=1, expand=True)

# %%
noteData[['Condition', 'Condition Description']]
# Out:
#      Condition                              Condition Description
# 0          New   A brand-new, unused, unopened, undamaged item...
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# ...        ...                                                ...
# 6600       New   A brand-new, unused, unopened, undamaged item...
# 6601      Used   An item that has been used previously. The it...
# 6611       New   A brand-new, unused, unopened, undamaged item...
# 6612       New   A brand-new, unused, unopened, undamaged item...
# 6618       NaN                                                NaN
#
# [4475 rows x 2 columns]
